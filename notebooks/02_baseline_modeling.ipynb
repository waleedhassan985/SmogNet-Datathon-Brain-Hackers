# %% [markdown]
# # 02 · Baseline Modeling
#
# Explore adaptive rolling baselines learned from training data only.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_RAW = PROJECT_ROOT / "data" / "raw"
DATA_OUTPUTS = PROJECT_ROOT / "data" / "outputs"
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /Users/waleedhassan/Downloads/Datathon/Somgnet-V1.1.1

# %%
from src.data_loader import load_air_quality_data
from src.preprocessing import preprocess_air_quality_data, detect_pollutant_columns
from src.anomaly_detection import compute_rolling_baselines

train_raw, test_raw, metadata = load_air_quality_data(DATA_RAW)
train_df = preprocess_air_quality_data(train_raw, is_train=True)
pollutants = detect_pollutant_columns(train_df)
train_scored, baseline_reference = compute_rolling_baselines(train_df, pollutants)
train_scored.head()
# Out:
# [load] Warning: trimming 18305 training row(s) at or after the test start 2024-07-01 00:00:00 to prevent temporal leakage.
#               datetime  main_aqi       co    no    no2     o3    so2  pm2_5  \
# 0  2021-08-24 00:00:00         5  1228.33  0.00  27.76  40.41   6.02  66.96
# 1  2021-08-24 01:00:00         5  1134.87  0.00  24.33  46.49   6.20  64.50
# 2  2021-08-24 02:00:00         5  1361.85  0.94  39.41  30.76   6.91  64.21
# 3  2021-08-24 03:00:00         5  1682.28  8.38  51.41  27.18   9.06  64.75
# 4  2021-08-24 04:00:00         5  1054.76  3.07  27.08  91.55  21.70  59.86
#
#     pm10    nh3  ...  pm2_5_baseline_level  pm2_5_score  pm10_baseline_median  \
# 0  87.07  14.69  ...                global     0.055832                102.48
# 1  82.37  14.57  ...                global     0.033944                102.48
# 2  80.38  16.21  ...                global     0.031364                102.48
# ...
